# %%
import pickle

# %%
loaded_model=pickle.load(open("final_mlr_model.sav",'rb')) # loading the model
result=loaded_model.predict([[20000,40000,340000,0,1]]) #input 0 is the origin point bias is the initial value
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[70278.39945691]])
